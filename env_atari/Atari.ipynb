# %% [markdown]
# #Setup

# %%
# %pip install -U gym>=0.23.0
# %pip install -U gym[atari,accept-rom-license]
# Out:
# ...
#      |████████████████████████████████| 1.6 MB 5.3 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.4.2-py3-none-any.whl size=441027 sha256=e9dc42616a1bf1c20221bbb36bbcd7b174779e5460c69a1bd48bc7cce585f1e5
#   Stored in directory: /root/.cache/pip/wheels/87/67/2e/6147e7912fe37f5408b80d07527dab807c1d25f5c403a9538a
# Successfully built AutoROM.accept-rom-license
# ...

# %%
# !git clone https://github.com/Niels-vv/Safe-RL-With-DR.git
# Out:
# Cloning into 'Safe-RL-With-DR'...
# remote: Enumerating objects: 1929, done.
# remote: Counting objects: 100% (219/219), done.
# remote: Compressing objects: 100% (142/142), done.
# remote: Total 1929 (delta 70), reused 208 (delta 59), pack-reused 1710
# Receiving objects: 100% (1929/1929), 320.76 MiB | 16.99 MiB/s, done.
# Resolving deltas: 100% (917/917), done.
# Checking out files: 100% (405/405), done.

# %% [markdown]
# # Running Experiments

# %% [markdown]
# Training Base agent

# %%
# !PYTHONPATH=/content/Safe-RL-With-DR python /content/Safe-RL-With-DR/env_atari/agent_runner.py --max_episodes 500 --load_policy True
# Out:
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# /usr/local/lib/python3.7/dist-packages/gym/utils/seeding.py:139: DeprecationWarning: WARN: Function `hash_seed(seed, max_bytes)` is marked as deprecated and will be removed in the future.
#   "Function `hash_seed(seed, max_bytes)` is marked as deprecated and will be removed in the future. "
# /usr/local/lib/python3.7/dist-packages/gym/utils/seeding.py:176: DeprecationWarning: WARN: Function `_bigint_from_bytes(bytes)` is marked as deprecated and will be removed in the future.
#   "Function `_bigint_from_bytes(bytes)` is marked as deprecated and will be removed in the future. "
# Loaded DQN model
# Filling replay memory buffer...
# Filling memory buffer episode 0 done.
# Filling memory buffer episode 1 done.
# Filling memory buffer episode 2 done.
# Filling memory buffer episode 3 done.
# Filling memory buffer episode 4 done.
# Filling memory buffer episode 5 done.
# ...

# %%
# Analyse time
# !PYTHONPATH=/content/Safe-RL-With-DR python -m cProfile -s cumtime /content/Safe-RL-With-DR/env_atari/agent_runner.py --max_episodes 1 >> /content/stass.txt
# Out:
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]

# %% [markdown]
# Gather Observations using trained agent

# %%
# !PYTHONPATH=/content/Safe-RL-With-DR python /content/Safe-RL-With-DR/env_atari/agent_runner.py --store_obs True
# Out:
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# /usr/local/lib/python3.7/dist-packages/gym/utils/seeding.py:139: DeprecationWarning: WARN: Function `hash_seed(seed, max_bytes)` is marked as deprecated and will be removed in the future.
#   "Function `hash_seed(seed, max_bytes)` is marked as deprecated and will be removed in the future. "
# /usr/local/lib/python3.7/dist-packages/gym/utils/seeding.py:176: DeprecationWarning: WARN: Function `_bigint_from_bytes(bytes)` is marked as deprecated and will be removed in the future.
#   "Function `_bigint_from_bytes(bytes)` is marked as deprecated and will be removed in the future. "
# Storing observations...
# Stored 1000 / 10000 observations.
# Episode reward: -19.0
# Episode reward: -21.0
# Stored 2000 / 10000 observations.
# Episode reward: -20.0
# Stored 3000 / 10000 observations.
# Episode reward: -20.0
# Stored 4000 / 10000 observations.
# Episode reward: -20.0
# Stored 5000 / 10000 observations.
# ...

# %% [markdown]
# Train autoencoder on stored observations

# %%
# !PYTHONPATH=/content/Safe-RL-With-DR python /content/Safe-RL-With-DR/env_atari/ae.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Batch done. Loss: 1.1814846992492676
# Batch done. Loss: 1.1890392303466797
# Batch done. Loss: 1.1700053215026855
# Batch done. Loss: 1.1916826963424683
# Batch done. Loss: 1.1899462938308716
# Batch done. Loss: 1.1384587287902832
# Batch done. Loss: 1.1375535726547241
# Batch done. Loss: 1.1996492147445679
# Batch done. Loss: 1.241766095161438
# Batch done. Loss: 1.2164556980133057
# Batch done. Loss: 1.2174991369247437
# Batch done. Loss: 1.2198684215545654
# Batch done. Loss: 1.1885240077972412
# Batch done. Loss: 1.1829458475112915
# Batch done. Loss: 1.2777057886123657
# Batch done. Loss: 1.2669800519943237
# Batch done. Loss: 1.248890995979309
# Batch done. Loss: 1.2147257328033447
# Batch done. Loss: 1.1984916925430298
# Batch done. Loss: 1.194545865058899
# Batch done. Loss: 1.1438179016113281
# Batch done. Loss: 1.253570556640625
# Batch done. Loss: 1.1740549802780151
# Batch done. Loss: 1.1921913623809814
# ...

# %% [markdown]
# Train PCA agent on observations

# %%
# !PYTHONPATH=/content/Safe-RL-With-DR python /content/Safe-RL-With-DR/env_atari/pca.py

# %% [markdown]
# Train agent using pretrained AE

# %%
# !PYTHONPATH=/content/Safe-RL-With-DR python /content/Safe-RL-With-DR/env_atari/agent_runner.py --max_episodes 550 --variant ae --load_policy=True
# Out:
# A.L.E: Arcade Learning Environment (version 0.7.5+db37282)
# [Powered by Stella]
# Latent space: 7056
# Loaded DQN model
# Running dqn
# Episode 500 done. Score: 17.0. Steps: 1988. Epsilon: 0.02. Fps: 605671.2683954383
# Storing intermediate results
# Episode 501 done. Score: 21.0. Steps: 1676. Epsilon: 0.02. Fps: 535184.8880091358
# Episode 502 done. Score: 11.0. Steps: 2295. Epsilon: 0.02. Fps: 747819.1174642636
# Episode 503 done. Score: 20.0. Steps: 1721. Epsilon: 0.02. Fps: 514277.3713308635
# Episode 504 done. Score: 13.0. Steps: 2337. Epsilon: 0.02. Fps: 789535.9200966572
# Episode 505 done. Score: 16.0. Steps: 2260. Epsilon: 0.02. Fps: 725258.3810252487
# Episode 506 done. Score: 18.0. Steps: 1914. Epsilon: 0.02. Fps: 611044.1357893135
# Episode 507 done. Score: 13.0. Steps: 2208. Epsilon: 0.02. Fps: 722501.4223747854
# Episode 508 done. Score: 17.0. Steps: 2078. Epsilon: 0.02. Fps: 668951.0869598588
# ...

# %% [markdown]
# Train agent using PCA

# %%
# !PYTHONPATH=/content/Safe-RL-With-DR python /content/Safe-RL-With-DR/env_atari/agent_runner.py --max_episodes 500 --variant pca --load_policy=True
# Out:
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# /usr/local/lib/python3.7/dist-packages/gym/utils/seeding.py:139: DeprecationWarning: WARN: Function `hash_seed(seed, max_bytes)` is marked as deprecated and will be removed in the future.
#   "Function `hash_seed(seed, max_bytes)` is marked as deprecated and will be removed in the future. "
# /usr/local/lib/python3.7/dist-packages/gym/utils/seeding.py:176: DeprecationWarning: WARN: Function `_bigint_from_bytes(bytes)` is marked as deprecated and will be removed in the future.
#   "Function `_bigint_from_bytes(bytes)` is marked as deprecated and will be removed in the future. "
# PCA latent space: 1764
# PCA scalar: False
# Loaded DQN model
# Filling replay memory buffer...
# Filling memory buffer episode 0 done.
# Filling memory buffer episode 1 done.
# Filling memory buffer episode 2 done.
# Filling memory buffer episode 3 done.
# Filling memory buffer episode 4 done.
# ...

# %% [markdown]
# Train online ae agent

# %%
# !PYTHONPATH=/content/Safe-RL-With-DR python /content/Safe-RL-With-DR/env_atari/agent_runner.py --max_episodes 500 --variant ae --train_ae_online=True --load_ae=True
# Out:
# A.L.E: Arcade Learning Environment (version 0.7.5+db37282)
# [Powered by Stella]
# loaded ae
# Latent space: 7056
# Running dqn
# Episode 1 done. Score: -20.0. Steps: 1008. Epsilon: 0.9789039613024056. Fps: 461506.2146053924
# Episode 2 done. Score: -21.0. Steps: 763. Epsilon: 0.9704317807404166. Fps: 492649.9310344828
# Episode 3 done. Score: -21.0. Steps: 1031. Epsilon: 0.9591013744423391. Fps: 665793.290839107
# Episode 4 done. Score: -17.0. Steps: 1214. Epsilon: 0.9459311253064528. Fps: 541286.81364941
# Episode 5 done. Score: -21.0. Steps: 869. Epsilon: 0.9366160610201976. Fps: 387255.6498087548
# Episode 6 done. Score: -19.0. Steps: 1095. Epsilon: 0.9250103630603199. Fps: 568763.2049535604
# Episode 7 done. Score: -20.0. Steps: 1046. Epsilon: 0.9140598094038158. Fps: 518463.9546206571
# Episode 8 done. Score: -20.0. Steps: 988. Epsilon: 0.9038368636894699. Fps: 499876.03763570567
# Episode 9 done. Score: -21.0. Steps: 941. Epsilon: 0.8942077566156795. Fps: 554331.4696629214
# ...

# %% [markdown]
# Analyse using resultsmanager

# %%
# !PYTHONPATH=/content/Safe-RL-With-DR python /content/Safe-RL-With-DR/utils/ResultsManager.py
# Out:
# Retrieving observations...
# Average results for all agents
# 440
# 501
# 320
# 501
# 440
# 500
# Figure(640x480)

# %%
mv /content/Safe-RL-With-DR/env_atari/results_ae/PongNoFrameskip-v4/Results_pretrained_ae_nieuw_1.csv /content/Safe-RL-With-DR/env_atari/results/dqn/PongNoFrameskip-v4/Results_pretrained_ae_nieuw_1.csv
