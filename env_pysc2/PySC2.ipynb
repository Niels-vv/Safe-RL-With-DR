# %% [markdown]
# Pysc2 Research. Setup for running files on Pysc2.
#
# Based on notebook by:
#
# Author: Paul Steven Conyngham
#
# Contributors: Paul Steven Conyngham, Frank He, William Xu

# %% [markdown]
# # Install and Setup Pysc2

# %%
# !pip3 install -U PyDrive
# !pip3 install https://download.pytorch.org/whl/cu80/torch-0.3.1-cp36-cp36m-linux_x86_64.whl && pip install torchvision
# !apt-get -qq install -y libsm6 libxext6 && pip3 install -U opencv-python
# !apt-get install -y xvfb python-opengl
# Out:
# ...
# ERROR: torch-0.3.1-cp36-cp36m-linux_x86_64.whl is not a supported wheel on this platform.
# ...
#      |████████████████████████████████| 49.9 MB 17 kB/s
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   libgle3
# The following NEW packages will be installed:
#   python-opengl xvfb
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 1,281 kB of archives.
# ...

# %% [markdown]
# *Download* the headless SC2 client

# %%
#!wget http://blzdistsc2-a.akamaihd.net/Linux/SC2.4.0.2.zip
#!unzip -P iagreetotheeula SC2.4.0.2.zip
# !wget http://blzdistsc2-a.akamaihd.net/Linux/SC2.4.10.zip
# !unzip -P iagreetotheeula SC2.4.10.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#    creating: StarCraftII/Battle.net/Cache/02/ef/
#   inflating: StarCraftII/Battle.net/Cache/02/ef/02eff872c7c7440a42e580dfb5ba197f41712a833cb8e725d51900c0f1a0e4c3.s2mh
#   inflating: StarCraftII/Battle.net/Cache/02/ef/02ef9de4146dd63844ba66faec3c1b041341ac751f1abe4136398cf191c706c7.s2mi
#    creating: StarCraftII/Battle.net/Cache/02/91/
#   inflating: StarCraftII/Battle.net/Cache/02/91/0291c58fe86df80835631c8fca91dc4de3d6a1046c39edee225511065a8de36f.s2mh
#    creating: StarCraftII/Battle.net/Cache/02/dd/
#   inflating: StarCraftII/Battle.net/Cache/02/dd/02dd9d06f47097daddbd0a2ab1e897ea5551a00fb7bdb2dae35eb1dc45e5b9fd.s2ml
#    creating: StarCraftII/Battle.net/Cache/02/4b/
#   inflating: StarCraftII/Battle.net/Cache/02/4b/024b7501e81e3b265f8edec2d22e1f5b95013fb70e54e7f1bfd84496ea46d15a.s2ml
#    creating: StarCraftII/Battle.net/Cache/02/b1/
# ...

# %%
# !pip install pysc2
# Out:
# ...
#      |████████████████████████████████| 260 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 11.8 MB 133 kB/s
# ...
#      |████████████████████████████████| 52 kB 951 kB/s
# ...
#      |████████████████████████████████| 2.3 MB 42.8 MB/s
# ...
#      |████████████████████████████████| 56 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 66 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 71 kB 7.0 MB/s
# ...
#   Created wheel for ordered-set: filename=ordered_set-4.0.2-py2.py3-none-any.whl size=8219 sha256=9b5dca787c4ee2ecc9d978a741ecace721b1112c0b9679a89a4b557ebbc2f313
#   Stored in directory: /root/.cache/pip/wheels/73/2b/f6/26e9f84153c25050fe7c09e88f8e32a6be3c7034a38c418319
# ...
#   Created wheel for mpyq: filename=mpyq-0.2.5-py3-none-any.whl size=6488 sha256=1d029edd6b0a00d42d23628b343815cc5dc5643da2cc36d283e1c74b3737b220
#   Stored in directory: /root/.cache/pip/wheels/d9/c4/c5/195dcd599cc36de237e88cdceb5a10e20d0178e7310442261e
# ...

# %% [markdown]
# Choose Mini Game

# %%
# !wget https://github.com/deepmind/pysc2/raw/master/pysc2/maps/mini_games/MoveToBeacon.SC2Map
# Out:
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# --2021-09-30 13:11:11--  https://github.com/deepmind/pysc2/raw/master/pysc2/maps/mini_games/MoveToBeacon.SC2Map
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/deepmind/pysc2/master/pysc2/maps/mini_games/MoveToBeacon.SC2Map [following]
# --2021-09-30 13:11:11--  https://raw.githubusercontent.com/deepmind/pysc2/master/pysc2/maps/mini_games/MoveToBeacon.SC2Map
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# ...

# %% [markdown]
# End of Mini games

# %%
# !mkdir StarCraftII/Maps/mini_games
# Out:
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# mkdir: cannot create directory ‘StarCraftII/Maps/mini_games’: File exists

# %% [markdown]
# Move chosen mini game

# %%
# !mv MoveToBeacon.SC2Map /content/StarCraftII/Maps/mini_games/
# !ls /content/StarCraftII/Maps/mini_games/
# !apt-get remove libtcmalloc*
# Out:
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# BuildMarines.SC2Map	      DefeatZerglingsAndBanelings.SC2Map
# CollectMineralsAndGas.SC2Map  FindAndDefeatZerglings.SC2Map
# CollectMineralShards.SC2Map   MoveToBeacon.SC2Map
# DefeatRoaches.SC2Map
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ...

# %%
# !mv StarCraftII /root
# Out:
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.

# %%
# !git clone https://github.com/Niels-vv/Safe-RL-With-DR.git
# Out:
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# Cloning into 'Safe-RL-With-DR'...
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (29/29), done.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# remote: Total 38 (delta 8), reused 32 (delta 5), pack-reused 0
# ...

# %% [markdown]
# # Running Experiments

# %%
# !PYTHONPATH=/content/Safe-RL-With-DR timeout -s 2 5m python /content/Safe-RL-With-DR/env_pysc2/AgentRunner.py --map MoveToBeacon
# Out:
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ...

# %%
# !PYTHONPATH=/content/Safe-RL-With-DR timeout -s 2 20s python /content/Safe-RL-With-DR/PySC2/PPO_Base/random_agent_test.py --map MoveToBeacon
# Out:
# Traceback (most recent call last):
#   File "/content/Safe-RL-With-DR/PySC2/PPO_Base/random_agent_test.py", line 28, in <module>
#     from pysc2 import maps
# ModuleNotFoundError: No module named 'pysc2'

# %% [markdown]
# Get Network Weights

# %%
from google.colab import files

files.download('./pytorch/data/SC2QAgent')
